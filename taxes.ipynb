# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
import chardet
with open('taxes.csv', 'rb') as f:
    result = chardet.detect(f.read())  # or readline if the file is large

# %%
pd.read_csv('taxes.csv', encoding=result['encoding'])
# Out:
#         Job ID Time charter was arranged:    Out   Done        Date  \
# 0     56761190                       3:25   4:01   4:37  01/01/2018
# 1     56761612                       4:10   4:25   4:57  01/01/2018
# 2     56761654                       4:24   4:59   5:29  01/01/2018
# 3     56761700                       5:33   6:04   6:28  01/01/2018
# 4     56770777                       9:18   9:30   9:39  01/01/2018
# 5     56761858                      10:59  11:15  11:59  01/01/2018
# 6     56761892                      13:07  13:22  14:43  01/01/2018
# 7     56761954                      13:20  13:39  14:11  01/01/2018
# 8     56774412                      14:42  14:54  16:47  01/01/2018
# 9     56779871                       3:13   3:28   3:38  01/02/2018
# 10    56779941                       3:29   3:54   4:09  01/02/2018
# 11    56779970                       4:27   4:45   5:11  01/02/2018
# 12    56780018                       4:34   4:53   5:01  01/02/2018
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-9c989e092031> in <module>
# ----> 1 ('taxes.csv').columns
#
# AttributeError: 'str' object has no attribute 'columns'

# %%
taxes.columns = taxes.columns.str.replace(' ', '_')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-d6fee8282eda> in <module>
# ----> 1 taxes.columns = taxes.columns.str.replace(' ', '_')
#
# NameError: name 'taxes' is not defined

# %%
#taxi = pd.read_csv('taxi.csv', 'encoding='latin1')
#my = pd.read_csv('taxes.csv')

# %%
#import codecs
#with codecs.open(file_name, "r",encoding='utf-8', errors='ignore') as fdata:
